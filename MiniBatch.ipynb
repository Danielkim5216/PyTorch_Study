# %%
import torch 
import torch.nn as nn 
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset #tensordataset
from torch.utils.data import DataLoader #dataloader

# %%
x_train  =  torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  90], 
                               [96,  98,  100],   
                               [73,  66,  70]])  
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
dataset = TensorDataset(x_train,y_train)

# %%
dataloader = DataLoader(dataset,batch_size=2,shuffle=True) #shuffle = shuffle dataset

# %%
model = nn.Linear(3,1) #input = 3 , output = 1
optimizer = torch.optim.SGD(model.parameters(),lr=1e-5)

# %%
epochs = 200
for epoch in range(epochs+1):
    for batch_idx, samples in enumerate(dataloader):
        x_train,y_train=samples
        #h(x) 계산
        prediction = model(x_train)
        #loss 
        loss = F.mse_loss(prediction,y_train)
        #loss로 h(x) 계산
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, epochs, batch_idx+1, len(dataloader),
        loss.item()
        ))
# Out:
# Epoch    0/200 Batch 1/3 Cost: 3.376412
# Epoch    0/200 Batch 2/3 Cost: 3.196314
# Epoch    0/200 Batch 3/3 Cost: 0.724353
# Epoch    1/200 Batch 1/3 Cost: 3.308923
# Epoch    1/200 Batch 2/3 Cost: 0.348491
# Epoch    1/200 Batch 3/3 Cost: 1.161433
# Epoch    2/200 Batch 1/3 Cost: 4.099930
# Epoch    2/200 Batch 2/3 Cost: 0.969569
# Epoch    2/200 Batch 3/3 Cost: 0.538724
# Epoch    3/200 Batch 1/3 Cost: 0.223856
# Epoch    3/200 Batch 2/3 Cost: 4.230781
# Epoch    3/200 Batch 3/3 Cost: 0.227708
# Epoch    4/200 Batch 1/3 Cost: 3.483539
# Epoch    4/200 Batch 2/3 Cost: 0.767735
# Epoch    4/200 Batch 3/3 Cost: 0.713769
# Epoch    5/200 Batch 1/3 Cost: 4.205058
# Epoch    5/200 Batch 2/3 Cost: 0.481923
# Epoch    5/200 Batch 3/3 Cost: 0.517611
# Epoch    6/200 Batch 1/3 Cost: 0.059639
# Epoch    6/200 Batch 2/3 Cost: 4.792996
# Epoch    6/200 Batch 3/3 Cost: 1.129555
# Epoch    7/200 Batch 1/3 Cost: 4.102386
# Epoch    7/200 Batch 2/3 Cost: 1.425348
# ...

# %%
new_var = torch.FloatTensor([[73,80,75]])
pred_y = model(new_var)
print("훈련 후 입력이 73,80,75일때 예측값 :",pred_y)
# Out:
# 훈련 후 입력이 73,80,75일때 예측값 : tensor([[149.6002]], grad_fn=<AddmmBackward0>)
